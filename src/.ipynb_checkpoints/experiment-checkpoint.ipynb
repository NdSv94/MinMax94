# %%
import pandas as pd
import numpy as np
import csv
from copy import deepcopy
from pandas import datetime
from copy import deepcopy
import gc
import random
import datetime
import csv
from copy import deepcopy
from os import listdir
from os.path import isfile, join, isdir
from tqdm import tqdm_notebook
from Downloader import Extractor
from Preprocessing import Preprocessor, set_onelevel, set_multilevel
import pickle
import xgboost as xgb

# %%
def create_xgb_matrix(df, test_label):
        
    features = [col for col in df.columns.levels[0] if col.startswith('data_')]
    
    X_lag = np.arange(-6, 0, 0.5)
    add = [(col, 0) for col in features if (col != 'data_' + test_label) ]

    X_label = [(feature, lag) for feature in features for lag in X_lag] + add
    y_label = [('data_' + test_label, 0)]

    X = df[X_label].values
    y = df[y_label].values.reshape(-1, 1)

    dxgb = xgb.DMatrix(X, y)

    return dxgb

# %%
#Quantile Regression objective. Smoothing is performed by Huber function
def quantile_huber_loss(preds, dtrain, _alpha, _delta):
    labels = dtrain.get_label()
    x = preds - labels
    loss = (x < (-_alpha * _delta)) * (-_alpha * x) + \
            ((x >= (-_alpha * _delta)) & (x < ((1. - _alpha) * _delta))) * (1. / (2 * _delta) * x ** 2) + \
            ((1. - _alpha) * x) * (x > ((1. - _alpha) * _delta))
    loss = np.sum(loss) / len(loss)
    return 'huber_quant', loss

#Grad and Hess of Huber quantile loss used for optimization in xgboost
def quantile_huber_obj(preds, dtrain, _alpha, _delta):
    labels = dtrain.get_label()
    x = preds - labels
    grad = (x < (-_alpha * _delta)) * (-_alpha) + \
            ((x >= (-_alpha * _delta)) & (x < ((1. - _alpha) * _delta))) * (1. / _delta * x) + \
            (1. - _alpha) * (x > ((1. - _alpha) * _delta))
    hess =  (1. / _delta) * ((x >= (-_alpha * _delta)) & (x < ((1. - _alpha) * _delta)))
    return grad, hess 

# Quantile Regression.
def quantile_loss(preds, dtrain, _alpha, _delta):
    labels = dtrain.get_label()
    x = preds - labels
    loss = (_alpha - 1.0) * x * (x < 0) + \
            (_alpha * x) * (x >= 0)
    loss = np.mean(loss)
    return 'quant_error', loss

#Grad and Hess of quantile loss used for optimization in xgboost. Gradient is smoothed by adding linear comp.??
def quantile_obj(preds, dtrain, _alpha, _delta): 
    labels = dtrain.get_label()
    x = labels - preds 
    grad = (x < ((_alpha - 1.0) * _delta)) * (1.0 - _alpha) + \
            ((x >= ((_alpha - 1.0) * _delta)) & (x < (_alpha * _delta))) * (-1. / _delta * x) + \
           (-_alpha) * (x > (_alpha * _delta)) 

    hess = ((x >= ((_alpha - 1.0) * _delta)) & (x < (_alpha * _delta))) * (1. / _delta) 
    return grad, hess

# %%
# getting file tree in directory "data_csv", which contains raw unfiltered data
mypath = './data_csv/Raw'
dateparse = pd.to_datetime
station_files = [f for f in listdir(mypath) if isfile(join(mypath, f)) if int(f.split('_', 1)[0])]

# reading loaded csv files from data_csv directory, output is a list (length=number of stations) of raw df 
raw_lmeteo_list = [pd.read_csv(mypath + '/' + station, index_col=0, 
                    dtype={'station_id': int,'date_time': str}, 
                    date_parser = dateparse, parse_dates = ['date_time']) 
                   for station in tqdm_notebook(station_files[:20])]

#fix problems with indexing, later this will be solved in loading part
for elem in raw_lmeteo_list:
    elem.reset_index(drop=True, inplace=True)

raw_data = pd.concat(raw_lmeteo_list)
raw_data['id'] = random.sample(range(len(raw_data)), len(raw_data))
raw_data['valid'] = True
raw_data = raw_data.reset_index(drop=True)

del raw_lmeteo_list
gc.collect()

raw_data
# Out:
#          station_data_id  sensor_id    data  station_id  sensor_type_id  \
# 0              7511082.0     6359.0  7553.0         613            16.0
# 1              7511082.0     6348.0    53.0         613             2.0
# 2              7511082.0     6347.0    17.0         613             1.0
# 3              7511082.0     6349.0    61.0         613             3.0
# 4              7511082.0     6350.0   846.0         613             4.0
# 5              7511083.0     6359.0  7545.0         613            16.0
# 6              7511083.0     6348.0    56.0         613             2.0
# 7              7511083.0     6347.0    19.0         613             1.0
# 8              7511083.0     6349.0    62.0         613             3.0
# 9              7511083.0     6350.0   845.0         613             4.0
# 10             7511084.0     6359.0  7545.0         613            16.0
# 11             7511084.0     6348.0    59.0         613             2.0
# ...

# %%
# %%time
preprocessor = Preprocessor()
pivoted_df = preprocessor.PivotTable(raw_data)
del raw_data

patterns_list = preprocessor.CreatePatternList(pivoted_df)
del pivoted_df

patterns_interpolated = preprocessor.InterpolatePatterns(patterns_list)
del patterns_list

patterns_lagged = preprocessor.CreateLaggedTable(patterns_interpolated)
del patterns_interpolated

final = pd.concat(patterns_lagged).reset_index(drop=True)
# Out:
# CPU times: user 5min 41s, sys: 4.47 s, total: 5min 45s
# Wall time: 5min 42s

# %%
test_label = 't_underroad'

train = final[final[('date_time', 0)] < '2015-06']
val = final[final[('date_time', 0)] >= '2015-06']

dtrain = create_xgb_matrix(train, test_label)
dval = create_xgb_matrix(val, test_label)
dfinal = create_xgb_matrix(final, test_label)

# %%
from sklearn.metrics import mean_squared_error as mse
import xgboost as xgb
from functools import partial

params = {}

params["eval_metric"] = 'mae'
params["eta"] = 0.05
params["lambda"] = 0.8
params["subsample"] = 0.5
params["min_child_weight"] = 1.
params["colsample_bytree"] = 0.7
params["max_depth"] = 8
params["silent"] = 1
params["gamma"] = 0.1
delta = 1.
#delta = 1.
watchlist = [(dtrain, 'train'), (dval, 'valid')]

#-----------------------------------------------------------------------------------------------
print('-----------MEDIAN-----------')
alpha = 0.5
clf = xgb.train(params, dtrain, 200, watchlist, verbose_eval=20)
train_median = clf.predict(dtrain)
val_median = clf.predict(dval)

#-----------------------------------------------------------------------------------------------
print('-----------UPPER-----------')
alpha = 0.99
clf_upper = xgb.train(params, dtrain, 400, watchlist, partial(quantile_huber_obj, _alpha=alpha, _delta=delta), 
                partial(quantile_huber_loss, _alpha=alpha, _delta=delta), 
                verbose_eval=50)
train_upper = clf_upper.predict(dtrain)
val_upper = clf_upper.predict(dval)

#-----------------------------------------------------------------------------------------------
print('-----------LOWER-----------')
alpha = 0.01
clf_lower = xgb.train(params, dtrain, 200, watchlist, partial(quantile_huber_obj, _alpha=alpha, _delta=delta), 
                partial(quantile_huber_loss, _alpha=alpha, _delta=delta), 
                verbose_eval=50)
train_lower = clf_lower.predict(dtrain)
val_lower = clf_lower.predict(dval)
# Out:
# -----------MEDIAN-----------
# [0]	train-mae:126.499	valid-mae:140.771
# [20]	train-mae:45.4894	valid-mae:50.8334
# [40]	train-mae:16.4982	valid-mae:18.6385
# [60]	train-mae:6.23901	valid-mae:7.17654
# [80]	train-mae:2.79795	valid-mae:3.32367
# [100]	train-mae:1.82874	valid-mae:2.27617
# [120]	train-mae:1.60782	valid-mae:2.03869
# [140]	train-mae:1.54842	valid-mae:1.97965
# [160]	train-mae:1.51926	valid-mae:1.95497
# [180]	train-mae:1.50604	valid-mae:1.95274
# -----------UPPER-----------
# [0]	train-mae:4612.38	valid-mae:5247.95	train-huber_quant:46.1842	valid-huber_quant:52.5252
# [50]	train-mae:2502.35	valid-mae:2836.45	train-huber_quant:26.4099	valid-huber_quant:29.553
# [100]	train-mae:815.11	valid-mae:889.837	train-huber_quant:11.8348	valid-huber_quant:11.9664
# [150]	train-mae:242.021	valid-mae:236.044	train-huber_quant:5.17593	valid-huber_quant:4.61669
# [200]	train-mae:230.913	valid-mae:225.701	train-huber_quant:4.44189	valid-huber_quant:3.99185
# ...

# %%
import pickle
path = 'estimators/pima.pickle.' + test_label
pickle.dump(clf, open(path + '_median', 'wb'))
pickle.dump(clf_upper, open(path + '_upper', 'wb'))
pickle.dump(clf_lower, open(path + '_lower', 'wb'))

# %%
def plot_result(self, station, start='2015-01-01', end='2016-01-01', sensors=None):
        
        #selecting sensors for which prediction was made and confidence intervals were created 
        to_plot = [column for column in self.prediction_.columns.tolist() if ('predicted' in column)]
        
        if sensors is None:
            sensors = [re.sub('predicted_', '', sensor) for sensor in to_plot]
        
        #temperature trends(t_air, t_road, t_underroad) should be plotted on the same figure (together)
        t_sensors = [sensor for sensor in sensors if ('t_' in sensor)]
        
        #other trends should be plotted the following way: one figure for each trend 
        other_sensors = [sensor for sensor in sensors if sensor not in t_sensors] 
        
        #selecting the exact station and time interval
        df_plot = self.prediction_[self.prediction_['station_id']==station]
        df_plot = df_plot[(df_plot['date_time'] >= start) & (df_plot['date_time'] <= end)]
        
        cols = ['b', 'g', 'm'][:len(t_sensors)] + len(other_sensors) * ['b']
        
        i = 0
        plt.figure(figsize=(30, 10))
        for sensor in t_sensors + other_sensors:
            for elem in [True, False]:
                cond = df_plot['valid'] == elem
                if elem:
                    plt.plot_date(df_plot[cond].date_time, df_plot[cond][sensor], cols[i],
                              linestyle='none', marker='o', label=sensor, markersize=6)
                    
                else:
                    plt.plot_date(df_plot[cond].date_time, df_plot[cond][sensor], 'r.',
                                  linestyle='none', marker='o', label='_nolegend_', markersize=6)
                
                if sensor in [re.sub('predicted_', '', sensor) for sensor in to_plot]:
                    plt.plot(df_plot.date_time, df_plot['upper_' + sensor], label='_nolegend_', c=cols[i], alpha=0.5)
                    plt.plot(df_plot.date_time, df_plot['lower_' + sensor], label='_nolegend_', c=cols[i], alpha=0.5)    
                    plt.fill_between(df_plot['date_time'].values, df_plot['lower_' + sensor], 
                                df_plot['upper_' + sensor], facecolor=cols[i], 
                                 alpha=.2)
            plt.title(sensor, fontsize=24)
            plt.legend(loc='upper right', fontsize=14)
            i+=1
            if i >= len(t_sensors):
                plt.grid(which='both')
                plt.show()
                plt.figure(figsize=(30, 10))
    pass

# %%
class Filter():
    def __init__(self, sensors=['t_road', 't_air', 't_underroad'], output='table'
                 path_to_filter='estimators/pima.pickle.'):
        self.sensors = sensors
        self.path = path_to_filter
        self.output = output
    
    def verify(self, df, inplace=True):
        
        invalid_ids = []
        for test_label in self.sensors:            
            
            dtest = create_xgb_matrix(df, test_label)
            
            # --------Upper/Lower---------
            model_upper = pickle.load(open(self.path + test_label + '_upper', 'rb'))
            model_lower = pickle.load(open(self.path + test_label + '_lower', 'rb'))
            
            y_upper = model_upper.predict(dtest).reshape(-1, 1)
            y_lower = model_lower.predict(dtest).reshape(-1, 1)
            y_true = dtest.get_label().reshape(-1, 1)
            
            if self.output == 'table':
                self.df_filtered = deepcopy(df)
                self.df_filtered[('valid_' + test_label, 0)] = ((y_true < y_upper) & (y_true > y_lower))
                self.verified = True
                return self.df_filtered
            
            elif self.output == 'ids':
                ids = df[('id_' + test_label, 0)][~df[('valid_' + test_label, 0)]].values
                invalid_ids.extend(ids)
                
        return invalid_ids
    
    def plot_filter_result(self, df):
        
        pass

# %%
filt = Filter()
filt.verify(final)

# %%
self, station, start='2015-01-01', end='2016-01-01', sensors=None
# Out:
# feature data_dampness                                                  \
# lag              -6.0        -5.5        -5.0        -4.5        -4.0
# 0          918.074380  936.972452  957.071625  969.099174  987.977961
# 1          936.972452  957.071625  969.099174  987.977961  981.644983
# 2          957.071625  969.099174  987.977961  981.644983  954.746696
# 3          969.099174  987.977961  981.644983  954.746696  924.988975
# 4          987.977961  981.644983  954.746696  924.988975  902.479890
# 5          981.644983  954.746696  924.988975  902.479890  888.842424
# 6          954.746696  924.988975  902.479890  888.842424  881.145455
# 7          924.988975  902.479890  888.842424  881.145455  875.827453
# 8          902.479890  888.842424  881.145455  875.827453  867.109091
# 9          888.842424  881.145455  875.827453  867.109091  851.254545
# 10         881.145455  875.827453  867.109091  851.254545  833.625689
# ...

# %%
def UnLagtable(df_lagged):
    df
    return df

# %%
from Preprocessing import set_onelevel, set_multilevel
z = final.loc[:,final.columns.get_level_values(1).isin({0})]
z.columns = z.columns.droplevel('lag')
z = set_multilevel(z)
# Out:
#                  id                                                   valid  \
#         t_underroad      t_air     t_road   pressure   dampness t_underroad
# 0         6220826.0  6328922.0  1457310.0  4559310.0  6223118.0        True
# 1         6374118.0  3848119.0  1640032.0  5874295.0  4592580.0        True
# 2         2238299.0  1065531.0  2325447.0  1716157.0  2701192.0        True
# 3          591199.0  3453748.0  1730730.0  5616800.0  1712377.0        True
# 4         1284982.0  6061958.0  1952713.0  6720597.0  6084538.0        True
# 5         4589760.0  2401459.0    13149.0  3865975.0  3062421.0        True
# 6         2029159.0  4733787.0  6053792.0   429236.0  4927882.0        True
# 7         4954773.0  6731221.0  3727664.0   395900.0  5636250.0        True
# 8         2158338.0  6484339.0  5603045.0  5948766.0    11753.0        True
# 9         1376402.0  4200211.0  5698169.0  3718271.0  6349802.0        True
# ...
